# %% [markdown]
# # Lab | Customer Analysis Round 2

# %%
# import libraries
import pandas as pd
import numpy as np
import datetime

# %%
# load csv file
df1 = pd.read_csv('files_for_lab/csv_files/marketing_customer_analysis.csv')

# %% [markdown]
# ## EXERCISES:

# %% [markdown]
# ### 1. Show the dataframe shape.

# %%
# number of rows and columns
df1.shape
# Out:
# (10910, 26)

# %% [markdown]
# ### 2. Standardize header names.

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
def standard_cols(dataframe):
    '''Standardize column names into lowercase and replace spaces with underscore.'''
    dataframe.columns = [col.lower().replace(' ','_') for col in df1.columns]
standard_cols(df1)
df1.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
# 1                        0.0                  1   Personal Auto   Personal L3
# 2                        0.0                  2   Personal Auto   Personal L3
# 3                        0.0                  2  Corporate Auto  Corporate L3
# 4                        NaN                  7   Personal Auto   Personal L2
#
#    renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   vehicle_size vehicle_type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize          NaN
#
# [5 rows x 26 columns]

# %%
df1 = df1.drop('unnamed:_0', axis=1) #dropping column which is has the same values as the index

# %% [markdown]
# ### 3/4. Numerical and Categorical Columns

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10910 non-null  object
#  1   state                          10279 non-null  object
#  2   customer_lifetime_value        10910 non-null  float64
#  3   response                       10279 non-null  object
#  4   coverage                       10910 non-null  object
#  5   education                      10910 non-null  object
#  6   effective_to_date              10910 non-null  object
#  7   employmentstatus               10910 non-null  object
#  8   gender                         10910 non-null  object
#  9   income                         10910 non-null  int64
#  10  location_code                  10910 non-null  object
#  11  marital_status                 10910 non-null  object
#  12  monthly_premium_auto           10910 non-null  int64
#  13  months_since_last_claim        10277 non-null  float64
#  14  months_since_policy_inception  10910 non-null  int64
#  15  number_of_open_complaints      10277 non-null  float64
#  16  number_of_policies             10910 non-null  int64
#  17  policy_type                    10910 non-null  object
#  18  policy                         10910 non-null  object
#  19  renew_offer_type               10910 non-null  object
#  20  sales_channel                  10910 non-null  object
#  21  total_claim_amount             10910 non-null  float64
#  22  vehicle_class                  10288 non-null  object
#  23  vehicle_size                   10288 non-null  object
#  24  vehicle_type                   5428 non-null   object
# dtypes: float64(4), int64(4), object(17)
# memory usage: 2.1+ MB

# %% [markdown]
# #### Numerical Variables

# %% [markdown]
# 1. customer_lifetime_value
# 2. months_since_last_claim
# 3. income
# 4. monthly_premium_auto
# 5. months_since_policy_inception
# 6. number_of_open_complaints
# 7. number_of_policies
# 8. total_claim_amount

# %% [markdown]
# #### Categorical Variables

# %% [markdown]
# 1. customer
# 2. state
# 3. response
# 4. coverage
# 5. education
# 6. effective_to_date
# 7. employmentstatus
# 8. gender
# 9. location_code
# 10. marital_status
# 11. policy_type
# 12. policy
# 13. renew_offer_type
# 14. sales_channel
# 15. vehicle_class
# 16. vehicle_size
# 17. vehicle_type (dropped)

# %% [markdown]
# ### Data Cleaning and Observation

# %%
# Dealing with duplicates
df1.duplicated().value_counts()
df2 = df1.drop_duplicates()

# %%
df2.vehicle_type.value_counts(dropna=False)
# Out:
# NaN    5465
# A      5408
# Name: vehicle_type, dtype: int64

# %%
#deciding to drop the vehicle_type column since there is only 1 unique value available and more than 50% is NaN
#variable is also very vague and not helpful
df2 = df2.drop('vehicle_type', axis=1)

# %%
df2.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# 0                            52                       0.0                   9
# 1                            26                       0.0                   1
# 2                            31                       0.0                   2
# 3                             3                       0.0                   2
# 4                            31                       NaN                   7
#
#       policy_type        policy  renew_offer_type  sales_channel  \
# 0  Corporate Auto  Corporate L3            Offer3          Agent
# 1   Personal Auto   Personal L3            Offer4    Call Center
# 2   Personal Auto   Personal L3            Offer3    Call Center
# 3  Corporate Auto  Corporate L3            Offer2         Branch
# 4   Personal Auto   Personal L2            Offer1         Branch
#
#   total_claim_amount  vehicle_class vehicle_size
# 0         292.800000  Four-Door Car      Medsize
# 1         744.924331  Four-Door Car      Medsize
# 2         480.000000            SUV      Medsize
# 3         484.013411  Four-Door Car      Medsize
# 4         707.925645  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %%
#Rounding off to 2 decimal places
df2.customer_lifetime_value = round(df2.customer_lifetime_value,2)
df2.total_claim_amount = round(df2.total_claim_amount,2)

# %%
df2['gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df2['vehicle_class'].unique()
# Out:
# array(['Four-Door Car', 'SUV', 'Two-Door Car', 'Sports Car', 'Luxury Car',
#        'Luxury SUV', nan], dtype=object)

# %%
df2['vehicle_size'].unique()
# Out:
# array(['Medsize', 'Small', 'Large', nan], dtype=object)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10873 entries, 0 to 10909
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10873 non-null  object
#  1   state                          10259 non-null  object
#  2   customer_lifetime_value        10873 non-null  float64
#  3   response                       10259 non-null  object
#  4   coverage                       10873 non-null  object
#  5   education                      10873 non-null  object
#  6   effective_to_date              10873 non-null  object
#  7   employmentstatus               10873 non-null  object
#  8   gender                         10873 non-null  object
#  9   income                         10873 non-null  int64
#  10  location_code                  10873 non-null  object
#  11  marital_status                 10873 non-null  object
#  12  monthly_premium_auto           10873 non-null  int64
#  13  months_since_last_claim        10250 non-null  float64
#  14  months_since_policy_inception  10873 non-null  int64
#  15  number_of_open_complaints      10250 non-null  float64
#  16  number_of_policies             10873 non-null  int64
#  17  policy_type                    10873 non-null  object
#  18  policy                         10873 non-null  object
#  19  renew_offer_type               10873 non-null  object
#  20  sales_channel                  10873 non-null  object
#  21  total_claim_amount             10873 non-null  float64
#  22  vehicle_class                  10265 non-null  object
#  23  vehicle_size                   10265 non-null  object
# dtypes: float64(4), int64(4), object(16)
# memory usage: 2.1+ MB

# %% [markdown]
# ### 5. Check and deal with NaN values.

# %%
df3 = df2 #copy dataframe for as safety precaution before starting to deal with null values

# %%
def check_na(dataframe):
    '''This function uses the dataframe as a parameter to check whether it has any null values.'''
    return dataframe.isna().sum()
    return dataframe.isna().value_counts()
check_na(df3)
# Out:
# customer                           0
# state                            614
# customer_lifetime_value            0
# response                         614
# coverage                           0
# education                          0
# effective_to_date                  0
# employmentstatus                   0
# gender                             0
# income                             0
# location_code                      0
# marital_status                     0
# monthly_premium_auto               0
# months_since_last_claim          623
# months_since_policy_inception      0
# number_of_open_complaints        623
# number_of_policies                 0
# policy_type                        0
# policy                             0
# renew_offer_type                   0
# sales_channel                      0
# total_claim_amount                 0
# vehicle_class                    608
# vehicle_size                     608
# dtype: int64

# %%
df3.isna().corr()
# Out:
#                                customer     state  customer_lifetime_value  \
# customer                            NaN       NaN                      NaN
# state                               NaN  1.000000                      NaN
# customer_lifetime_value             NaN       NaN                      NaN
# response                            NaN  1.000000                      NaN
# coverage                            NaN       NaN                      NaN
# education                           NaN       NaN                      NaN
# effective_to_date                   NaN       NaN                      NaN
# employmentstatus                    NaN       NaN                      NaN
# gender                              NaN       NaN                      NaN
# income                              NaN       NaN                      NaN
# location_code                       NaN       NaN                      NaN
# marital_status                      NaN       NaN                      NaN
# monthly_premium_auto                NaN       NaN                      NaN
# months_since_last_claim             NaN  0.009976                      NaN
# months_since_policy_inception       NaN       NaN                      NaN
# number_of_open_complaints           NaN  0.009976                      NaN
# number_of_policies                  NaN       NaN                      NaN
# policy_type                         NaN       NaN                      NaN
# policy                              NaN       NaN                      NaN
# renew_offer_type                    NaN       NaN                      NaN
# sales_channel                       NaN       NaN                      NaN
# total_claim_amount                  NaN       NaN                      NaN
# vehicle_class                       NaN -0.009250                      NaN
# vehicle_size                        NaN -0.009250                      NaN
#
#                                response  coverage  education  \
# customer                            NaN       NaN        NaN
# state                          1.000000       NaN        NaN
# customer_lifetime_value             NaN       NaN        NaN
# response                       1.000000       NaN        NaN
# coverage                            NaN       NaN        NaN
# education                           NaN       NaN        NaN
# effective_to_date                   NaN       NaN        NaN
# employmentstatus                    NaN       NaN        NaN
# gender                              NaN       NaN        NaN
# income                              NaN       NaN        NaN
# location_code                       NaN       NaN        NaN
# marital_status                      NaN       NaN        NaN
# monthly_premium_auto                NaN       NaN        NaN
# months_since_last_claim        0.009976       NaN        NaN
# months_since_policy_inception       NaN       NaN        NaN
# number_of_open_complaints      0.009976       NaN        NaN
# number_of_policies                  NaN       NaN        NaN
# policy_type                         NaN       NaN        NaN
# policy                              NaN       NaN        NaN
# renew_offer_type                    NaN       NaN        NaN
# sales_channel                       NaN       NaN        NaN
# total_claim_amount                  NaN       NaN        NaN
# vehicle_class                 -0.009250       NaN        NaN
# vehicle_size                  -0.009250       NaN        NaN
#
#                                effective_to_date  employmentstatus  gender  \
# customer                                     NaN               NaN     NaN
# state                                        NaN               NaN     NaN
# customer_lifetime_value                      NaN               NaN     NaN
# response                                     NaN               NaN     NaN
# coverage                                     NaN               NaN     NaN
# education                                    NaN               NaN     NaN
# effective_to_date                            NaN               NaN     NaN
# employmentstatus                             NaN               NaN     NaN
# gender                                       NaN               NaN     NaN
# income                                       NaN               NaN     NaN
# location_code                                NaN               NaN     NaN
# marital_status                               NaN               NaN     NaN
# monthly_premium_auto                         NaN               NaN     NaN
# months_since_last_claim                      NaN               NaN     NaN
# months_since_policy_inception                NaN               NaN     NaN
# number_of_open_complaints                    NaN               NaN     NaN
# number_of_policies                           NaN               NaN     NaN
# policy_type                                  NaN               NaN     NaN
# policy                                       NaN               NaN     NaN
# renew_offer_type                             NaN               NaN     NaN
# sales_channel                                NaN               NaN     NaN
# total_claim_amount                           NaN               NaN     NaN
# vehicle_class                                NaN               NaN     NaN
# vehicle_size                                 NaN               NaN     NaN
#
#                                income  ...  months_since_policy_inception  \
# customer                          NaN  ...                            NaN
# state                             NaN  ...                            NaN
# customer_lifetime_value           NaN  ...                            NaN
# response                          NaN  ...                            NaN
# coverage                          NaN  ...                            NaN
# education                         NaN  ...                            NaN
# effective_to_date                 NaN  ...                            NaN
# employmentstatus                  NaN  ...                            NaN
# gender                            NaN  ...                            NaN
# income                            NaN  ...                            NaN
# location_code                     NaN  ...                            NaN
# marital_status                    NaN  ...                            NaN
# monthly_premium_auto              NaN  ...                            NaN
# months_since_last_claim           NaN  ...                            NaN
# months_since_policy_inception     NaN  ...                            NaN
# number_of_open_complaints         NaN  ...                            NaN
# number_of_policies                NaN  ...                            NaN
# policy_type                       NaN  ...                            NaN
# policy                            NaN  ...                            NaN
# renew_offer_type                  NaN  ...                            NaN
# sales_channel                     NaN  ...                            NaN
# total_claim_amount                NaN  ...                            NaN
# vehicle_class                     NaN  ...                            NaN
# vehicle_size                      NaN  ...                            NaN
#
#                                number_of_open_complaints  number_of_policies  \
# customer                                             NaN                 NaN
# state                                           0.009976                 NaN
# customer_lifetime_value                              NaN                 NaN
# response                                        0.009976                 NaN
# coverage                                             NaN                 NaN
# education                                            NaN                 NaN
# effective_to_date                                    NaN                 NaN
# employmentstatus                                     NaN                 NaN
# gender                                               NaN                 NaN
# income                                               NaN                 NaN
# location_code                                        NaN                 NaN
# marital_status                                       NaN                 NaN
# monthly_premium_auto                                 NaN                 NaN
# months_since_last_claim                         1.000000                 NaN
# months_since_policy_inception                        NaN                 NaN
# number_of_open_complaints                       1.000000                 NaN
# number_of_policies                                   NaN                 NaN
# policy_type                                          NaN                 NaN
# policy                                               NaN                 NaN
# renew_offer_type                                     NaN                 NaN
# sales_channel                                        NaN                 NaN
# total_claim_amount                                   NaN                 NaN
# vehicle_class                                   0.008892                 NaN
# vehicle_size                                    0.008892                 NaN
#
#                                policy_type  policy  renew_offer_type  \
# customer                               NaN     NaN               NaN
# state                                  NaN     NaN               NaN
# customer_lifetime_value                NaN     NaN               NaN
# response                               NaN     NaN               NaN
# coverage                               NaN     NaN               NaN
# education                              NaN     NaN               NaN
# effective_to_date                      NaN     NaN               NaN
# employmentstatus                       NaN     NaN               NaN
# gender                                 NaN     NaN               NaN
# income                                 NaN     NaN               NaN
# location_code                          NaN     NaN               NaN
# marital_status                         NaN     NaN               NaN
# monthly_premium_auto                   NaN     NaN               NaN
# months_since_last_claim                NaN     NaN               NaN
# months_since_policy_inception          NaN     NaN               NaN
# number_of_open_complaints              NaN     NaN               NaN
# number_of_policies                     NaN     NaN               NaN
# policy_type                            NaN     NaN               NaN
# policy                                 NaN     NaN               NaN
# renew_offer_type                       NaN     NaN               NaN
# sales_channel                          NaN     NaN               NaN
# total_claim_amount                     NaN     NaN               NaN
# vehicle_class                          NaN     NaN               NaN
# vehicle_size                           NaN     NaN               NaN
#
#                                sales_channel  total_claim_amount  \
# customer                                 NaN                 NaN
# state                                    NaN                 NaN
# customer_lifetime_value                  NaN                 NaN
# response                                 NaN                 NaN
# coverage                                 NaN                 NaN
# education                                NaN                 NaN
# effective_to_date                        NaN                 NaN
# employmentstatus                         NaN                 NaN
# gender                                   NaN                 NaN
# income                                   NaN                 NaN
# location_code                            NaN                 NaN
# marital_status                           NaN                 NaN
# monthly_premium_auto                     NaN                 NaN
# months_since_last_claim                  NaN                 NaN
# months_since_policy_inception            NaN                 NaN
# number_of_open_complaints                NaN                 NaN
# number_of_policies                       NaN                 NaN
# policy_type                              NaN                 NaN
# policy                                   NaN                 NaN
# renew_offer_type                         NaN                 NaN
# sales_channel                            NaN                 NaN
# total_claim_amount                       NaN                 NaN
# vehicle_class                            NaN                 NaN
# vehicle_size                             NaN                 NaN
#
#                                vehicle_class  vehicle_size
# customer                                 NaN           NaN
# state                              -0.009250     -0.009250
# customer_lifetime_value                  NaN           NaN
# response                           -0.009250     -0.009250
# coverage                                 NaN           NaN
# education                                NaN           NaN
# effective_to_date                        NaN           NaN
# employmentstatus                         NaN           NaN
# gender                                   NaN           NaN
# income                                   NaN           NaN
# location_code                            NaN           NaN
# marital_status                           NaN           NaN
# monthly_premium_auto                     NaN           NaN
# months_since_last_claim             0.008892      0.008892
# months_since_policy_inception            NaN           NaN
# number_of_open_complaints           0.008892      0.008892
# number_of_policies                       NaN           NaN
# policy_type                              NaN           NaN
# policy                                   NaN           NaN
# renew_offer_type                         NaN           NaN
# sales_channel                            NaN           NaN
# total_claim_amount                       NaN           NaN
# vehicle_class                       1.000000      1.000000
# vehicle_size                        1.000000      1.000000
#
# [24 rows x 24 columns]

# %% [markdown]
# Missing Values Correlation = 1
# - state & response
# - months_since_last_claim & number_of_open_complaints
# - vehicle_class & vehicle_size

# %%
# look at records with missing values
df_na= df3[df3.isna().any(axis=1)]
df_na
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 4      QA50777      Oregon                  9025.07       No   Premium
# 5      HO81102         NaN                  4745.18      NaN     Basic
# 11     GE63585         NaN                  2420.71      NaN     Basic
# 23     NQ71171  California                  5107.07       No     Basic
# 51     FT56968     Arizona                  2590.10       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10883  FD64348      Oregon                 22563.62       No     Basic
# 10890  VQ78876      Oregon                  4660.40       No     Basic
# 10894  EX63393         NaN                  6314.49      NaN  Extended
# 10905  FE99816      Nevada                 15563.37       No   Premium
# 10909  IV32877         NaN                  6857.52      NaN     Basic
#
#                   education effective_to_date employmentstatus gender  income  \
# 4                  Bachelor           1/17/11    Medical Leave      F   23675
# 5      High School or Below           2/14/11         Employed      M   50549
# 11                 Bachelor            2/7/11         Employed      M   31710
# 23                 Bachelor            2/2/11         Employed      M   70174
# 51     High School or Below            1/3/11         Employed      M   22398
# ...                     ...               ...              ...    ...     ...
# 10883  High School or Below           1/17/11         Employed      M   23046
# 10890              Bachelor            2/3/11         Employed      F   89834
# 10894                Master           2/27/11         Employed      F   66947
# 10905              Bachelor           1/19/11       Unemployed      F       0
# 10909              Bachelor            1/8/11       Unemployed      M       0
#
#        ... months_since_policy_inception number_of_open_complaints  \
# 4      ...                            31                       NaN
# 5      ...                            73                       0.0
# 11     ...                            29                       0.0
# 23     ...                            80                       NaN
# 51     ...                            76                       NaN
# ...    ...                           ...                       ...
# 10883  ...                             7                       3.0
# 10890  ...                            11                       0.0
# 10894  ...                            12                       0.0
# 10905  ...                            40                       NaN
# 10909  ...                             1                       0.0
#
#        number_of_policies     policy_type        policy  renew_offer_type  \
# 4                       7   Personal Auto   Personal L2            Offer1
# 5                       7   Personal Auto   Personal L3            Offer1
# 11                      1  Corporate Auto  Corporate L3            Offer1
# 23                      7   Personal Auto   Personal L2            Offer1
# 51                      1   Personal Auto   Personal L1            Offer1
# ...                   ...             ...           ...               ...
# 10883                   2   Personal Auto   Personal L3            Offer4
# 10890                   1  Corporate Auto  Corporate L3            Offer1
# 10894                   6   Personal Auto   Personal L1            Offer3
# 10905                   7   Personal Auto   Personal L1            Offer3
# 10909                   3   Personal Auto   Personal L1            Offer4
#
#        sales_channel total_claim_amount  vehicle_class vehicle_size
# 4             Branch             707.93  Four-Door Car      Medsize
# 5              Agent             292.80  Four-Door Car      Medsize
# 11       Call Center             199.55   Two-Door Car      Medsize
# 23             Agent             128.90  Four-Door Car      Medsize
# 51             Agent             321.60  Four-Door Car        Large
# ...              ...                ...            ...          ...
# 10883         Branch               1.69            NaN          NaN
# 10890         Branch              43.16            NaN          NaN
# 10894          Agent             374.40  Four-Door Car        Small
# 10905            Web            1214.40     Luxury Car      Medsize
# 10909            Web            1021.72            SUV      Medsize
#
# [1739 rows x 24 columns]

# %%
df_na[['gender', 'state']].value_counts(dropna=False)
# Out:
# gender  state
# F       NaN           332
# M       NaN           282
#         California    223
# F       California    175
#         Oregon        160
# M       Oregon        136
# F       Arizona       125
# M       Arizona       106
#         Nevada         58
# F       Nevada         52
#         Washington     52
# M       Washington     38
# dtype: int64

# %%
df_na.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              1739.000000   1739.000000           1739.000000
# mean               8079.602450  36905.345026             93.202990
# std                6958.839611  30269.139228             34.709706
# min                1918.120000      0.000000             61.000000
# 25%                4098.650000      0.000000             68.000000
# 50%                5704.980000  32918.000000             82.000000
# 75%                9042.325000  61817.000000            109.000000
# max               58207.130000  99845.000000            295.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count              1116.000000                    1739.000000
# mean                 15.538530                      48.278321
# std                  10.120855                      28.062720
# min                   0.000000                       0.000000
# 25%                   7.000000                      25.000000
# 50%                  15.000000                      50.000000
# 75%                  24.000000                      72.000000
# max                  35.000000                      99.000000
#
#        number_of_open_complaints  number_of_policies  total_claim_amount
# count                1116.000000         1739.000000         1739.000000
# mean                    0.376344            3.036803          439.178936
# std                     0.918146            2.436967          301.223300
# min                     0.000000            1.000000            0.380000
# 25%                     0.000000            1.000000          265.205000
# 50%                     0.000000            2.000000          379.200000
# 75%                     0.000000            4.000000          542.400000
# max                     5.000000            9.000000         2552.340000

# %%
len(df_na)/len(df3) #percent of missing values in the dataframe
# Out:
# 0.15993745976271498

# %%
# Remove observations with null values which represents 16% of all observation and look to be random
# We will still have more than 9134 records after deleting missing values
def drop_na(df):
    '''This function drops all missing values in the dataframe.'''
    df = df.dropna()
    return df
df4 = drop_na(df3)

# %%
df4.info()
check_na(df4).sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9134 entries, 0 to 10908
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer_lifetime_value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective_to_date              9134 non-null   datetime64[ns]
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location_code                  9134 non-null   object
#  11  marital_status                 9134 non-null   object
#  12  monthly_premium_auto           9134 non-null   int64
#  13  months_since_last_claim        9134 non-null   float64
#  14  months_since_policy_inception  9134 non-null   int64
#  15  number_of_open_complaints      9134 non-null   float64
#  16  number_of_policies             9134 non-null   int64
#  17  policy_type                    9134 non-null   object
#  18  policy                         9134 non-null   object
#  19  renew_offer_type               9134 non-null   object
#  20  sales_channel                  9134 non-null   object
#  21  total_claim_amount             9134 non-null   float64
#  22  vehicle_class                  9134 non-null   object
#  23  vehicle_size                   9134 non-null   object
#  24  month                          9134 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(5), object(15)
# memory usage: 1.8+ MB
# 0

# %%
df4.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona                  4809.22       No     Basic   College
# 1  KX64629  California                  2228.53       No     Basic   College
# 2  LZ68649  Washington                 14947.92       No     Basic  Bachelor
# 3  XL78013      Oregon                 22332.44      Yes  Extended   College
# 6  IW72280  California                  5035.04       No     Basic    Doctor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 6           2/14/11         Employed      F   37405  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# 0                            52                       0.0                   9
# 1                            26                       0.0                   1
# 2                            31                       0.0                   2
# 3                             3                       0.0                   2
# 6                            99                       3.0                   4
#
#       policy_type        policy  renew_offer_type  sales_channel  \
# 0  Corporate Auto  Corporate L3            Offer3          Agent
# 1   Personal Auto   Personal L3            Offer4    Call Center
# 2   Personal Auto   Personal L3            Offer3    Call Center
# 3  Corporate Auto  Corporate L3            Offer2         Branch
# 6  Corporate Auto  Corporate L2            Offer2         Branch
#
#   total_claim_amount  vehicle_class vehicle_size
# 0             292.80  Four-Door Car      Medsize
# 1             744.92  Four-Door Car      Medsize
# 2             480.00            SUV      Medsize
# 3             484.01  Four-Door Car      Medsize
# 6             287.56  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 6.1. Datetime format

# %%
def transform_to_date(column):
    column = pd.to_datetime(column, errors='coerce')
    return column
df4.effective_to_date = transform_to_date(df4.effective_to_date)
# Out:
# /Users/RachelleFlores/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df4
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona                  4809.22       No     Basic
# 1      KX64629  California                  2228.53       No     Basic
# 2      LZ68649  Washington                 14947.92       No     Basic
# 3      XL78013      Oregon                 22332.44      Yes  Extended
# 6      IW72280  California                  5035.04       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona                  2771.66       No     Basic
# 10904  QI63521      Nevada                 19228.46       No     Basic
# 10906  KX53892      Oregon                  5259.44       No     Basic
# 10907  TL39050     Arizona                 23893.30       No  Extended
# 10908  WA60547  California                 11971.98       No   Premium
#
#                   education effective_to_date employmentstatus gender  income  \
# 0                   College        2011-02-18         Employed      M   48029
# 1                   College        2011-01-18       Unemployed      F       0
# 2                  Bachelor        2011-02-10         Employed      M   22139
# 3                   College        2011-01-11         Employed      M   49078
# 6                    Doctor        2011-02-14         Employed      F   37405
# ...                     ...               ...              ...    ...     ...
# 10903               College        2011-01-07         Employed      M   59855
# 10904  High School or Below        2011-02-24       Unemployed      M       0
# 10906               College        2011-01-06         Employed      F   61146
# 10907              Bachelor        2011-02-06         Employed      F   39837
# 10908               College        2011-02-13         Employed      F   64195
#
#        ... months_since_policy_inception number_of_open_complaints  \
# 0      ...                            52                       0.0
# 1      ...                            26                       0.0
# 2      ...                            31                       0.0
# 3      ...                             3                       0.0
# 6      ...                            99                       3.0
# ...    ...                           ...                       ...
# 10903  ...                            82                       4.0
# 10904  ...                            32                       0.0
# 10906  ...                            68                       0.0
# 10907  ...                            63                       0.0
# 10908  ...                            27                       4.0
#
#        number_of_policies     policy_type        policy  renew_offer_type  \
# 0                       9  Corporate Auto  Corporate L3            Offer3
# 1                       1   Personal Auto   Personal L3            Offer4
# 2                       2   Personal Auto   Personal L3            Offer3
# 3                       2  Corporate Auto  Corporate L3            Offer2
# 6                       4  Corporate Auto  Corporate L2            Offer2
# ...                   ...             ...           ...               ...
# 10903                   1   Personal Auto   Personal L2            Offer2
# 10904                   2   Personal Auto   Personal L2            Offer1
# 10906                   6   Personal Auto   Personal L3            Offer2
# 10907                   2  Corporate Auto  Corporate L3            Offer1
# 10908                   6   Personal Auto   Personal L1            Offer1
#
#        sales_channel total_claim_amount  vehicle_class vehicle_size
# 0              Agent             292.80  Four-Door Car      Medsize
# 1        Call Center             744.92  Four-Door Car      Medsize
# 2        Call Center             480.00            SUV      Medsize
# 3             Branch             484.01  Four-Door Car      Medsize
# 6             Branch             287.56  Four-Door Car      Medsize
# ...              ...                ...            ...          ...
# 10903         Branch             355.20   Two-Door Car      Medsize
# 10904         Branch             897.60     Luxury SUV      Medsize
# 10906         Branch             273.02  Four-Door Car      Medsize
# 10907            Web             381.31     Luxury SUV      Medsize
# 10908         Branch             618.29            SUV      Medsize
#
# [9134 rows x 24 columns]

# %% [markdown]
# ### 6.2. Extract the months from the dataset and store in a separate column.

# %%
def extract_month(fromcol):
    '''Extracts month from datetime column. Don't forget to assign function result to a variable with new column name'''
    newcol = fromcol.dt.month
    return newcol
df4['month'] = extract_month(df4.effective_to_date)
# Out:
# /var/folders/dg/rfjw5drd4hd12g7gk7g9v89m0000gn/T/ipykernel_8086/551279118.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['month'] = extract_month(df4.effective_to_date)

# %%
df4.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona                  4809.22       No     Basic   College
# 1  KX64629  California                  2228.53       No     Basic   College
# 2  LZ68649  Washington                 14947.92       No     Basic  Bachelor
# 3  XL78013      Oregon                 22332.44      Yes  Extended   College
# 6  IW72280  California                  5035.04       No     Basic    Doctor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0        2011-02-18         Employed      M   48029  ...
# 1        2011-01-18       Unemployed      F       0  ...
# 2        2011-02-10         Employed      M   22139  ...
# 3        2011-01-11         Employed      M   49078  ...
# 6        2011-02-14         Employed      F   37405  ...
#
#   number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# 1                       0.0                  1   Personal Auto   Personal L3
# 2                       0.0                  2   Personal Auto   Personal L3
# 3                       0.0                  2  Corporate Auto  Corporate L3
# 6                       3.0                  4  Corporate Auto  Corporate L2
#
#    renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 0            Offer3          Agent              292.80  Four-Door Car
# 1            Offer4    Call Center              744.92  Four-Door Car
# 2            Offer3    Call Center              480.00            SUV
# 3            Offer2         Branch              484.01  Four-Door Car
# 6            Offer2         Branch              287.56  Four-Door Car
#
#   vehicle_size month
# 0      Medsize     2
# 1      Medsize     1
# 2      Medsize     2
# 3      Medsize     1
# 6      Medsize     2
#
# [5 rows x 25 columns]

# %% [markdown]
# ### 6.3. Filter the data to show only the information for the first quarter.

# %%
def q1(df):
    '''Filter the dataframe to only the first quarter records(January, February, March)'''
    return df[df['month'].isin({1,2,3})]
df_clean_q1 = q1(df4)
df_clean_q1
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona                  4809.22       No     Basic
# 1      KX64629  California                  2228.53       No     Basic
# 2      LZ68649  Washington                 14947.92       No     Basic
# 3      XL78013      Oregon                 22332.44      Yes  Extended
# 6      IW72280  California                  5035.04       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona                  2771.66       No     Basic
# 10904  QI63521      Nevada                 19228.46       No     Basic
# 10906  KX53892      Oregon                  5259.44       No     Basic
# 10907  TL39050     Arizona                 23893.30       No  Extended
# 10908  WA60547  California                 11971.98       No   Premium
#
#                   education effective_to_date employmentstatus gender  income  \
# 0                   College        2011-02-18         Employed      M   48029
# 1                   College        2011-01-18       Unemployed      F       0
# 2                  Bachelor        2011-02-10         Employed      M   22139
# 3                   College        2011-01-11         Employed      M   49078
# 6                    Doctor        2011-02-14         Employed      F   37405
# ...                     ...               ...              ...    ...     ...
# 10903               College        2011-01-07         Employed      M   59855
# 10904  High School or Below        2011-02-24       Unemployed      M       0
# 10906               College        2011-01-06         Employed      F   61146
# 10907              Bachelor        2011-02-06         Employed      F   39837
# 10908               College        2011-02-13         Employed      F   64195
#
#        ... number_of_open_complaints number_of_policies     policy_type  \
# 0      ...                       0.0                  9  Corporate Auto
# 1      ...                       0.0                  1   Personal Auto
# 2      ...                       0.0                  2   Personal Auto
# 3      ...                       0.0                  2  Corporate Auto
# 6      ...                       3.0                  4  Corporate Auto
# ...    ...                       ...                ...             ...
# 10903  ...                       4.0                  1   Personal Auto
# 10904  ...                       0.0                  2   Personal Auto
# 10906  ...                       0.0                  6   Personal Auto
# 10907  ...                       0.0                  2  Corporate Auto
# 10908  ...                       4.0                  6   Personal Auto
#
#              policy  renew_offer_type  sales_channel  total_claim_amount  \
# 0      Corporate L3            Offer3          Agent              292.80
# 1       Personal L3            Offer4    Call Center              744.92
# 2       Personal L3            Offer3    Call Center              480.00
# 3      Corporate L3            Offer2         Branch              484.01
# 6      Corporate L2            Offer2         Branch              287.56
# ...             ...               ...            ...                 ...
# 10903   Personal L2            Offer2         Branch              355.20
# 10904   Personal L2            Offer1         Branch              897.60
# 10906   Personal L3            Offer2         Branch              273.02
# 10907  Corporate L3            Offer1            Web              381.31
# 10908   Personal L1            Offer1         Branch              618.29
#
#        vehicle_class vehicle_size month
# 0      Four-Door Car      Medsize     2
# 1      Four-Door Car      Medsize     1
# 2                SUV      Medsize     2
# 3      Four-Door Car      Medsize     1
# 6      Four-Door Car      Medsize     2
# ...              ...          ...   ...
# 10903   Two-Door Car      Medsize     1
# 10904     Luxury SUV      Medsize     2
# 10906  Four-Door Car      Medsize     1
# 10907     Luxury SUV      Medsize     2
# 10908            SUV      Medsize     2
#
# [9134 rows x 25 columns]
